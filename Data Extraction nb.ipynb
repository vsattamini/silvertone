# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

from glob import glob

import os

# os.chdir allows you to change directories, like cd in the Terminal
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# Subtitute for your own path to database folder. Structure afterwards is /databasename/files.wav
# "/content/drive/MyDrive/Emotion Datasets/Emotion Datasets/Audio/RAVDESS/Audio_Speech_Actors_01-24/*.wav")
path = '/content/drive/MyDrive/Emotion Datasets/Emotion Datasets/Audio'
# Out:
# Mounted at /content/drive

# %%
from audio_formating import Silvertone
from glob import glob
import numpy as np
import pandas as pd

# %%
from data_extraction import extract_ravdess, extract_crema, extract_savee, extract_tess

# %%
# ravdess = pd.DataFrame(extract_ravdess(trim=True))

# %%
# crema = pd.DataFrame(extract_crema(trim=True))

# %%
# df_rv_cr = pd.concat([ravdess,crema])

# %%
# df_rv_cr.to_csv("df_rv_cr.csv")

# %%
# df_rv_cr.head(2)

# %%
savee = pd.DataFrame(extract_savee(trim=True))
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/spectrum.py:224: UserWarning: n_fft=1024 is too small for input signal of length=1016
#   n_fft, y.shape[-1]

# %%
tess = pd.DataFrame(extract_tess(trim=True))

# %%
# df_final = pd.concat([ravdess,tess,crema,savee])

# %%
# df_final.head(2)

# %%
df_final.groupby('emotion').count()['tonnetz']
# Out:
# emotion
# angry        1923
# calm          192
# disgust      1923
# fearful      1923
# happy        1923
# neutral      1703
# sad          1723
# surprised     652
# Name: tonnetz, dtype: int64

# %%
df_rv_cr = pd.read_csv("df_rv_cr.csv")

# %%
df_final = pd.concat([df_rv_cr,tess,savee])

# %%
df_final.shape
# Out:
# (11962, 16)

# %%
df_final.to_csv("database_final_v3.csv")

# %%
df2 = df_final[df_final['emotion']!='surprised']

# %%
df2 =  df2[df2['emotion']!='calm']

# %%
df2.groupby('emotion').count()['tonnetz']
# Out:
# emotion
# angry      1923
# disgust    1923
# fearful    1923
# happy      1923
# neutral    1703
# sad        1723
# Name: tonnetz, dtype: int64
